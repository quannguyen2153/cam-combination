# %% [markdown]
# # Prepare

# %%
import warnings
warnings.filterwarnings('ignore')
import cv2
import sys
import os
sys.path.append(os.path.abspath('..'))
from typing import Union, List
from enum import Enum
import json
import os
import random
import torch
import shutil
from PIL import Image
import numpy as np

import torchvision.models as models

import matplotlib.pyplot as plt

import pytorch_grad_cam as cam
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget, ClassifierOutputSoftmaxTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.image import show_cam_on_image, \
    deprocess_image, \
    preprocess_image
class CAMType(Enum):
    GRAD_CAM = cam.GradCAM
    HI_RES_CAM = cam.HiResCAM
    GRAD_CAM_ELEMENT_WISE = cam.GradCAMElementWise
    ABLATION_CAM = cam.AblationCAM
    X_GRAD_CAM = cam.XGradCAM
    GRAD_CAM_PLUS_PLUS = cam.GradCAMPlusPlus
    SCORE_CAM = cam.ScoreCAM
    LAYER_CAM = cam.LayerCAM
    EIGEN_CAM = cam.EigenCAM
    EIGEN_GRAD_CAM = cam.EigenGradCAM
    KPCA_CAM = cam.KPCA_CAM
    RANDOM_CAM = cam.RandomCAM
    FULL_GRAD = cam.FullGrad

from typing import List, Callable

def get_cam(cam_type: CAMType, model: torch.nn.Module, target_layers: torch.nn.Module):
    cam_class = cam_type.value
    return cam_class(model=model, target_layers=target_layers)

def visualize(grayscale: torch.Tensor, rgb_img: np.ndarray):
    visualization = show_cam_on_image(rgb_img, grayscale, use_rgb=True)
    plt.imshow(visualization)
    plt.axis('off')
    plt.show()

def display_images_in_rows(rgb_img: np.ndarray, grayscale_list: List[torch.Tensor], labels: List[str]):
    """
    Displays a list of images in rows, with each row containing up to max_images_per_row images.
    
    Args:
        images (list of np.ndarray): List of images to display.
        labels (list of str): List of labels for each image.
        max_images_per_row (int): Maximum number of images per row (default is 4).
    """

    images = [rgb_img]

    for grayscale in grayscale_list:
        images.append(show_cam_on_image(rgb_img, grayscale, use_rgb=True))

    labels.insert(0, "Image")

    fig, axes = plt.subplots(1, 4, figsize=(15, 5))

    # Loop through the images and labels to display them
    for ax, img, label in zip(axes, images, labels):
        ax.imshow(img)  # Show the image
        ax.set_title(label)  # Set the title
        ax.axis('off')  # Hide axes

    plt.tight_layout()
    plt.show()

def execute_cam(
        img_path: str,
        model: torch.nn.Module,
        target_layers: List[torch.nn.Module],
        cam_type: CAMType,
        targets: Union[List[ClassifierOutputTarget], None] = None,
        visualization: bool = False,
        output_path: Union[str, None] = None
    ):
        model_name = "unknown"
        target_layer_name = "unknown"
        try:
            model_name = model._get_name()
            target_layer_name = target_layers[0]._get_name()
        except:
            pass

        print(f"Executing CAM on {model_name} with target layer {target_layer_name}:")

        img = np.array(Image.open(img_path).convert("RGB"))
        img = cv2.resize(img, (224, 224))
        img = np.float32(img) / 255
        input_tensor = preprocess_image(img, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

        # Forward to get target class if not specified
        if not targets:
            with torch.no_grad():
                predicted_class = model(input_tensor).max(1)[-1]
                targets = [ClassifierOutputTarget(predicted_class)]
                print(predicted_class)
                print(f"Target class: {labels[str(predicted_class.item())][1]}")

        cam = get_cam(cam_type=cam_type, model=model, target_layers=target_layers)

        # Generate the CAM
        grayscale_cam = cam(input_tensor=input_tensor, targets=targets)

        # Overlay the CAM on the image
        if visualization:
            # Convert the PIL image to a NumPy array for visualization
            rgb_img = np.array(rgb_img.resize((224, 224))) / 255.0  # Normalize the pixel values
            
            visualize(grayscale=grayscale_cam[0, :], rgb_img=rgb_img)

            # Optionally, you can save the resulting CAM visualization
            if output_path:
                Image.fromarray((visualization * 255).astype(np.uint8)).save(output_path)
                print(f"Saved output image to {output_path}")

        return grayscale_cam, input_tensor

labels = json.load(open("../pytorch_grad_cam/utils/imagenet_class_index.json"))

# %%
class PerturbationConfidenceMetric:
    def __init__(self, perturbation):
        self.perturbation = perturbation

    def __call__(self, input_tensor: torch.Tensor,
                 cams: np.ndarray,
                 targets: List[Callable],
                 model: torch.nn.Module,
                 return_visualization=False,
                 return_diff=True):

        if return_diff:
            with torch.no_grad():
                outputs = model(input_tensor)
                scores = [target(output).cpu().numpy()
                          for target, output in zip(targets, outputs)]
                scores = np.float32(scores)

        batch_size = input_tensor.size(0)
        perturbated_tensors = []
        for i in range(batch_size):
            cam = cams[i]
            tensor = self.perturbation(input_tensor[i, ...].cpu(),
                                       torch.from_numpy(cam))
            tensor = tensor.to(input_tensor.device)
            perturbated_tensors.append(tensor.unsqueeze(0))
        perturbated_tensors = torch.cat(perturbated_tensors)

        with torch.no_grad():
            outputs_after_imputation = model(perturbated_tensors)
        scores_after_imputation = [
            target(output).cpu().numpy() for target, output in zip(
                targets, outputs_after_imputation)]
        scores_after_imputation = np.float32(scores_after_imputation)

        if return_diff:
            result = scores_after_imputation - scores
        else:
            result = scores_after_imputation

        if return_visualization:
            return result, scores, scores_after_imputation, perturbated_tensors
        else:
            return result, scores, scores_after_imputation

def multiply_tensor_with_cam(input_tensor: torch.Tensor,
                             cam: torch.Tensor):
    """ Multiply an input tensor (after normalization)
        with a pixel attribution map
    """
    return input_tensor * cam
        
class CamMultImageConfidenceChange(PerturbationConfidenceMetric):
    def __init__(self):
        super(CamMultImageConfidenceChange,
              self).__init__(multiply_tensor_with_cam)
        
class DropInConfidence(CamMultImageConfidenceChange):
    def __init__(self):
        super(DropInConfidence, self).__init__()

    def __call__(self, *args, **kwargs):
        scores, scores_before, scores_after = super(DropInConfidence, self).__call__(*args, **kwargs)
        scores = -scores
        return np.maximum(scores, 0) / scores_before * 100


class IncreaseInConfidence(CamMultImageConfidenceChange):
    def __init__(self):
        super(IncreaseInConfidence, self).__init__()

    def __call__(self, *args, **kwargs):
        scores, bef_score, scores_after = super(IncreaseInConfidence, self).__call__(*args, **kwargs)
        return np.float32(scores > 0)

# %% [markdown]
# # Body

# %% [markdown]
# ## Choose model & method

# %%
model = models.vgg16(weights=models.VGG16_Weights.DEFAULT).eval()
target_layers = [model.features[28]]

# model = models.alexnet(weights=models.AlexNet_Weights.DEFAULT).eval()
# target_layers = [model.features[10]]

cam_metric = CamMultImageConfidenceChange()
drop_in_conf_metric = DropInConfidence()
increase_in_conf_metric = IncreaseInConfidence()

# %% [markdown]
# ## Average drop & Average increase

# %%
# Paths
input_folder = r"C:\Users\HaPham\Documents\ThesisXAI\Code\CAM-combination\ILSVRC2012\ILSVRC2012_img_val"
imputated_folder = "../imputated_images"

if os.path.exists(imputated_folder):
    shutil.rmtree(imputated_folder)
os.makedirs(imputated_folder)

# Generate a list of image names within the specified range
start_idx = 1
end_idx = 50000
num_images_to_sample = 100  # Adjust this to how many random images you want

all_image_names = [
    f"ILSVRC2012_val_{i:08d}.JPEG" for i in range(start_idx, end_idx + 1)
]
random_image_names = random.sample(all_image_names, num_images_to_sample)
random_image_names = ['ILSVRC2012_val_00048014.JPEG', 'ILSVRC2012_val_00040662.JPEG', 'ILSVRC2012_val_00021194.JPEG', 'ILSVRC2012_val_00038840.JPEG', 'ILSVRC2012_val_00026519.JPEG', 'ILSVRC2012_val_00026939.JPEG', 'ILSVRC2012_val_00000022.JPEG', 'ILSVRC2012_val_00000165.JPEG', 'ILSVRC2012_val_00028945.JPEG', 'ILSVRC2012_val_00032674.JPEG', 'ILSVRC2012_val_00026695.JPEG', 'ILSVRC2012_val_00043106.JPEG', 'ILSVRC2012_val_00038333.JPEG', 'ILSVRC2012_val_00018162.JPEG', 'ILSVRC2012_val_00004863.JPEG', 'ILSVRC2012_val_00034851.JPEG', 'ILSVRC2012_val_00004517.JPEG', 'ILSVRC2012_val_00010810.JPEG', 'ILSVRC2012_val_00011824.JPEG', 'ILSVRC2012_val_00020485.JPEG', 'ILSVRC2012_val_00048173.JPEG', 'ILSVRC2012_val_00041393.JPEG', 'ILSVRC2012_val_00033662.JPEG', 'ILSVRC2012_val_00045303.JPEG', 'ILSVRC2012_val_00004455.JPEG', 'ILSVRC2012_val_00011500.JPEG', 'ILSVRC2012_val_00025962.JPEG', 'ILSVRC2012_val_00043584.JPEG', 'ILSVRC2012_val_00036038.JPEG', 'ILSVRC2012_val_00001159.JPEG', 'ILSVRC2012_val_00036157.JPEG', 'ILSVRC2012_val_00047597.JPEG', 'ILSVRC2012_val_00044337.JPEG', 'ILSVRC2012_val_00003755.JPEG', 'ILSVRC2012_val_00043447.JPEG', 'ILSVRC2012_val_00031518.JPEG', 'ILSVRC2012_val_00041929.JPEG', 'ILSVRC2012_val_00010950.JPEG', 'ILSVRC2012_val_00023940.JPEG', 'ILSVRC2012_val_00034458.JPEG', 'ILSVRC2012_val_00003772.JPEG', 'ILSVRC2012_val_00017173.JPEG', 'ILSVRC2012_val_00035194.JPEG', 'ILSVRC2012_val_00013968.JPEG', 'ILSVRC2012_val_00007289.JPEG', 'ILSVRC2012_val_00035626.JPEG', 'ILSVRC2012_val_00001925.JPEG', 'ILSVRC2012_val_00018556.JPEG', 'ILSVRC2012_val_00005887.JPEG', 'ILSVRC2012_val_00037546.JPEG', 'ILSVRC2012_val_00037983.JPEG', 'ILSVRC2012_val_00028321.JPEG', 'ILSVRC2012_val_00006292.JPEG', 'ILSVRC2012_val_00010227.JPEG', 'ILSVRC2012_val_00020722.JPEG', 'ILSVRC2012_val_00010561.JPEG', 'ILSVRC2012_val_00040482.JPEG', 'ILSVRC2012_val_00042051.JPEG', 'ILSVRC2012_val_00001760.JPEG', 'ILSVRC2012_val_00021865.JPEG', 'ILSVRC2012_val_00010828.JPEG', 'ILSVRC2012_val_00043847.JPEG', 'ILSVRC2012_val_00036917.JPEG', 'ILSVRC2012_val_00047053.JPEG', 'ILSVRC2012_val_00002225.JPEG', 'ILSVRC2012_val_00014391.JPEG', 'ILSVRC2012_val_00023265.JPEG', 'ILSVRC2012_val_00025722.JPEG', 'ILSVRC2012_val_00035266.JPEG', 'ILSVRC2012_val_00000334.JPEG', 'ILSVRC2012_val_00009316.JPEG', 'ILSVRC2012_val_00037959.JPEG', 'ILSVRC2012_val_00015267.JPEG', 'ILSVRC2012_val_00045274.JPEG', 'ILSVRC2012_val_00005621.JPEG', 'ILSVRC2012_val_00009324.JPEG', 'ILSVRC2012_val_00036612.JPEG', 'ILSVRC2012_val_00012167.JPEG', 'ILSVRC2012_val_00013826.JPEG', 'ILSVRC2012_val_00039615.JPEG', 'ILSVRC2012_val_00003550.JPEG', 'ILSVRC2012_val_00018661.JPEG', 'ILSVRC2012_val_00037578.JPEG', 'ILSVRC2012_val_00032692.JPEG', 'ILSVRC2012_val_00022024.JPEG', 'ILSVRC2012_val_00011285.JPEG', 'ILSVRC2012_val_00017859.JPEG', 'ILSVRC2012_val_00025713.JPEG', 'ILSVRC2012_val_00027390.JPEG', 'ILSVRC2012_val_00045695.JPEG', 'ILSVRC2012_val_00038690.JPEG', 'ILSVRC2012_val_00016934.JPEG', 'ILSVRC2012_val_00027410.JPEG', 'ILSVRC2012_val_00039936.JPEG', 'ILSVRC2012_val_00025764.JPEG', 'ILSVRC2012_val_00024909.JPEG', 'ILSVRC2012_val_00003979.JPEG', 'ILSVRC2012_val_00035948.JPEG', 'ILSVRC2012_val_00044730.JPEG', 'ILSVRC2012_val_00041283.JPEG']

# %%
cam_type = CAMType.GRAD_CAM

# Initialize metrics
total_drop_in_conf = 0
total_increase_in_conf = 0
num_images = 0  # Track number of processed images

# Process the randomly selected images
for filename in random_image_names:
    img_path = os.path.join(input_folder, filename)

    if os.path.exists(img_path):  # Ensure the file exists
        # Execute CAM for the current image
        gray_scale, input_tensor = execute_cam(img_path=img_path, model=model, target_layers=target_layers, cam_type=cam_type)
        
        # Add threshold
        threshold = np.percentile(gray_scale, 50)
        
        gray_scale[gray_scale < threshold] = 0
        # gray_scale = gray_scale < threshold

        # Calculate predicted class and confidence score change
        predicted_class = model(input_tensor).max(1)[-1]
        targets = [ClassifierOutputSoftmaxTarget(predicted_class)]

        scores, scores_before, scores_after, visualizations = cam_metric(
            input_tensor, gray_scale, targets, model, return_visualization=True
        )

        # Calculate Drop in Confidence and Increase in Confidence
        drop_in_conf = drop_in_conf_metric(input_tensor, gray_scale, targets, model)
        increase_in_conf = increase_in_conf_metric(input_tensor, gray_scale, targets, model)

        # Accumulate the scores for averaging
        total_drop_in_conf += drop_in_conf
        total_increase_in_conf += increase_in_conf
        num_images += 1  # Increment image count

        # Process the visualization for display and scoring
        score = scores[0]

        # Save images to imputated folder
        visualization = visualizations[0].cpu().numpy().transpose((1, 2, 0))
        visualization = deprocess_image(visualization)
        Image.fromarray(visualization).save(os.path.join(imputated_folder, filename))

        # Print individual results
        print(f"Image: {filename}")
        print(f"Confidence before imputation: {scores_before}")
        print(f"Confidence after imputation: {scores_after}")
        print(f"The confidence increase raw: {score}")
        print(f"The drop in confidence percentage: {drop_in_conf}%")
        print(f"The increase in confidence: {increase_in_conf}")
        print("----------------------------------------")

# Calculate and print averages after processing all images
if num_images > 0:
    avg_drop_in_conf = total_drop_in_conf / num_images
    avg_increase_in_conf = total_increase_in_conf / num_images * 100
    print(f"\nNumber of images processed: {num_images}")
    print(f"Average Drop in Confidence: {avg_drop_in_conf}%")
    print(f"Average Increase in Confidence: {avg_increase_in_conf}%")
else:
    print("No valid images found in the specified folder.")
# Out:
# Executing CAM on VGG with target layer Conv2d:
# tensor([605])
# Target class: iPod
# Image: ILSVRC2012_val_00048014.JPEG
# Confidence before imputation: [[0.9759646]]
# Confidence after imputation: [[0.97425985]]
# The confidence increase raw: [-0.00170475]
# The drop in confidence percentage: [[0.17467359]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([748])
# Target class: purse
# Image: ILSVRC2012_val_00040662.JPEG
# Confidence before imputation: [[0.42008683]]
# Confidence after imputation: [[0.01459827]]
# The confidence increase raw: [-0.40548855]
# The drop in confidence percentage: [[96.52493]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([898])
# Target class: water_bottle
# Image: ILSVRC2012_val_00021194.JPEG
# Confidence before imputation: [[0.24797332]]
# Confidence after imputation: [[0.00338788]]
# The confidence increase raw: [-0.24458544]
# The drop in confidence percentage: [[98.63377]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([760])
# Target class: refrigerator
# Image: ILSVRC2012_val_00038840.JPEG
# Confidence before imputation: [[0.9940416]]
# Confidence after imputation: [[0.5653578]]
# The confidence increase raw: [-0.42868382]
# The drop in confidence percentage: [[43.125336]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([980])
# Target class: volcano
# Image: ILSVRC2012_val_00026519.JPEG
# Confidence before imputation: [[0.8553798]]
# Confidence after imputation: [[0.13710093]]
# The confidence increase raw: [-0.7182789]
# The drop in confidence percentage: [[83.971924]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([126])
# Target class: isopod
# Image: ILSVRC2012_val_00026939.JPEG
# Confidence before imputation: [[0.99842215]]
# Confidence after imputation: [[0.8311013]]
# The confidence increase raw: [-0.16732085]
# The drop in confidence percentage: [[16.758528]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([209])
# Target class: Chesapeake_Bay_retriever
# Image: ILSVRC2012_val_00000022.JPEG
# Confidence before imputation: [[0.06324018]]
# Confidence after imputation: [[0.00583907]]
# The confidence increase raw: [-0.05740111]
# The drop in confidence percentage: [[90.76683]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([937])
# Target class: broccoli
# Image: ILSVRC2012_val_00000165.JPEG
# Confidence before imputation: [[0.9990583]]
# Confidence after imputation: [[0.99920255]]
# The confidence increase raw: [0.00014424]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([203])
# Target class: West_Highland_white_terrier
# Image: ILSVRC2012_val_00028945.JPEG
# Confidence before imputation: [[0.904776]]
# Confidence after imputation: [[0.89837724]]
# The confidence increase raw: [-0.00639874]
# The drop in confidence percentage: [[0.7072179]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([954])
# Target class: banana
# Image: ILSVRC2012_val_00032674.JPEG
# Confidence before imputation: [[0.64645135]]
# Confidence after imputation: [[0.13745996]]
# The confidence increase raw: [-0.50899136]
# The drop in confidence percentage: [[78.73622]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([561])
# Target class: forklift
# Image: ILSVRC2012_val_00026695.JPEG
# Confidence before imputation: [[0.9999956]]
# Confidence after imputation: [[0.965366]]
# The confidence increase raw: [-0.03462958]
# The drop in confidence percentage: [[3.4629736]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([850])
# Target class: teddy
# Image: ILSVRC2012_val_00043106.JPEG
# Confidence before imputation: [[0.9326974]]
# Confidence after imputation: [[0.3350451]]
# The confidence increase raw: [-0.5976523]
# The drop in confidence percentage: [[64.077835]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([495])
# Target class: china_cabinet
# Image: ILSVRC2012_val_00038333.JPEG
# Confidence before imputation: [[0.99724907]]
# Confidence after imputation: [[0.9405001]]
# The confidence increase raw: [-0.05674899]
# The drop in confidence percentage: [[5.690553]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([12])
# Target class: house_finch
# Image: ILSVRC2012_val_00018162.JPEG
# Confidence before imputation: [[0.852396]]
# Confidence after imputation: [[0.13445888]]
# The confidence increase raw: [-0.7179371]
# The drop in confidence percentage: [[84.22578]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([694])
# Target class: paddlewheel
# Image: ILSVRC2012_val_00004863.JPEG
# Confidence before imputation: [[0.9999994]]
# Confidence after imputation: [[0.9989832]]
# The confidence increase raw: [-0.0010162]
# The drop in confidence percentage: [[0.10162002]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([248])
# Target class: Eskimo_dog
# Image: ILSVRC2012_val_00034851.JPEG
# Confidence before imputation: [[0.4604159]]
# Confidence after imputation: [[0.28302145]]
# The confidence increase raw: [-0.17739445]
# The drop in confidence percentage: [[38.529175]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([305])
# Target class: dung_beetle
# Image: ILSVRC2012_val_00004517.JPEG
# Confidence before imputation: [[0.92013]]
# Confidence after imputation: [[0.45452332]]
# The confidence increase raw: [-0.4656067]
# The drop in confidence percentage: [[50.60227]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([98])
# Target class: red-breasted_merganser
# Image: ILSVRC2012_val_00010810.JPEG
# Confidence before imputation: [[0.68175596]]
# Confidence after imputation: [[0.75035465]]
# The confidence increase raw: [0.06859869]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([763])
# Target class: revolver
# Image: ILSVRC2012_val_00011824.JPEG
# Confidence before imputation: [[0.9994036]]
# Confidence after imputation: [[0.7557444]]
# The confidence increase raw: [-0.2436592]
# The drop in confidence percentage: [[24.38046]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([746])
# Target class: puck
# Image: ILSVRC2012_val_00020485.JPEG
# Confidence before imputation: [[0.7053595]]
# Confidence after imputation: [[0.00061031]]
# The confidence increase raw: [-0.7047492]
# The drop in confidence percentage: [[99.913475]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([735])
# Target class: poncho
# Image: ILSVRC2012_val_00048173.JPEG
# Confidence before imputation: [[0.9730132]]
# Confidence after imputation: [[0.01128599]]
# The confidence increase raw: [-0.96172726]
# The drop in confidence percentage: [[98.8401]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([211])
# Target class: vizsla
# Image: ILSVRC2012_val_00041393.JPEG
# Confidence before imputation: [[0.9897141]]
# Confidence after imputation: [[0.9760172]]
# The confidence increase raw: [-0.01369691]
# The drop in confidence percentage: [[1.3839259]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([807])
# Target class: solar_dish
# Image: ILSVRC2012_val_00033662.JPEG
# Confidence before imputation: [[0.5625051]]
# Confidence after imputation: [[0.06101693]]
# The confidence increase raw: [-0.5014882]
# The drop in confidence percentage: [[89.15265]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([653])
# Target class: milk_can
# Image: ILSVRC2012_val_00045303.JPEG
# Confidence before imputation: [[0.45696172]]
# Confidence after imputation: [[0.1122114]]
# The confidence increase raw: [-0.34475031]
# The drop in confidence percentage: [[75.44402]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([586])
# Target class: half_track
# Image: ILSVRC2012_val_00004455.JPEG
# Confidence before imputation: [[0.9999417]]
# Confidence after imputation: [[0.9996567]]
# The confidence increase raw: [-0.00028503]
# The drop in confidence percentage: [[0.0285046]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([962])
# Target class: meat_loaf
# Image: ILSVRC2012_val_00011500.JPEG
# Confidence before imputation: [[0.82238984]]
# Confidence after imputation: [[0.61350495]]
# The confidence increase raw: [-0.2088849]
# The drop in confidence percentage: [[25.399742]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([641])
# Target class: maraca
# Image: ILSVRC2012_val_00025962.JPEG
# Confidence before imputation: [[0.7052517]]
# Confidence after imputation: [[0.02012938]]
# The confidence increase raw: [-0.6851223]
# The drop in confidence percentage: [[97.14579]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([536])
# Target class: dock
# Image: ILSVRC2012_val_00043584.JPEG
# Confidence before imputation: [[0.49611756]]
# Confidence after imputation: [[0.00780463]]
# The confidence increase raw: [-0.48831293]
# The drop in confidence percentage: [[98.42686]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([695])
# Target class: padlock
# Image: ILSVRC2012_val_00036038.JPEG
# Confidence before imputation: [[0.9970312]]
# Confidence after imputation: [[0.9684816]]
# The confidence increase raw: [-0.02854961]
# The drop in confidence percentage: [[2.863462]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([958])
# Target class: hay
# Image: ILSVRC2012_val_00001159.JPEG
# Confidence before imputation: [[0.9706044]]
# Confidence after imputation: [[0.42348224]]
# The confidence increase raw: [-0.5471222]
# The drop in confidence percentage: [[56.36922]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([6])
# Target class: stingray
# Image: ILSVRC2012_val_00036157.JPEG
# Confidence before imputation: [[0.9078361]]
# Confidence after imputation: [[0.3791337]]
# The confidence increase raw: [-0.5287024]
# The drop in confidence percentage: [[58.237648]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([267])
# Target class: standard_poodle
# Image: ILSVRC2012_val_00047597.JPEG
# Confidence before imputation: [[0.800983]]
# Confidence after imputation: [[0.60540634]]
# The confidence increase raw: [-0.19557667]
# The drop in confidence percentage: [[24.41708]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([597])
# Target class: holster
# Image: ILSVRC2012_val_00044337.JPEG
# Confidence before imputation: [[0.95589864]]
# Confidence after imputation: [[0.0273574]]
# The confidence increase raw: [-0.92854124]
# The drop in confidence percentage: [[97.13804]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([458])
# Target class: brass
# Image: ILSVRC2012_val_00003755.JPEG
# Confidence before imputation: [[0.7906359]]
# Confidence after imputation: [[0.85778755]]
# The confidence increase raw: [0.06715167]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([388])
# Target class: giant_panda
# Image: ILSVRC2012_val_00043447.JPEG
# Confidence before imputation: [[1.]]
# Confidence after imputation: [[0.99997735]]
# The confidence increase raw: [-2.2649765e-05]
# The drop in confidence percentage: [[0.00226498]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([721])
# Target class: pillow
# Image: ILSVRC2012_val_00031518.JPEG
# Confidence before imputation: [[0.26630247]]
# Confidence after imputation: [[0.02572888]]
# The confidence increase raw: [-0.24057359]
# The drop in confidence percentage: [[90.33848]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([232])
# Target class: Border_collie
# Image: ILSVRC2012_val_00041929.JPEG
# Confidence before imputation: [[0.763132]]
# Confidence after imputation: [[0.29431236]]
# The confidence increase raw: [-0.46881962]
# The drop in confidence percentage: [[61.433624]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([792])
# Target class: shovel
# Image: ILSVRC2012_val_00010950.JPEG
# Confidence before imputation: [[0.6403869]]
# Confidence after imputation: [[0.00751967]]
# The confidence increase raw: [-0.6328672]
# The drop in confidence percentage: [[98.82577]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([313])
# Target class: walking_stick
# Image: ILSVRC2012_val_00023940.JPEG
# Confidence before imputation: [[0.18065749]]
# Confidence after imputation: [[0.00238505]]
# The confidence increase raw: [-0.17827244]
# The drop in confidence percentage: [[98.679794]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([703])
# Target class: park_bench
# Image: ILSVRC2012_val_00034458.JPEG
# Confidence before imputation: [[0.96288735]]
# Confidence after imputation: [[0.08808698]]
# The confidence increase raw: [-0.8748004]
# The drop in confidence percentage: [[90.85179]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([752])
# Target class: racket
# Image: ILSVRC2012_val_00003772.JPEG
# Confidence before imputation: [[0.5566144]]
# Confidence after imputation: [[0.10752075]]
# The confidence increase raw: [-0.44909364]
# The drop in confidence percentage: [[80.68308]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([658])
# Target class: mitten
# Image: ILSVRC2012_val_00017173.JPEG
# Confidence before imputation: [[0.44766384]]
# Confidence after imputation: [[0.7116802]]
# The confidence increase raw: [0.26401633]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([551])
# Target class: face_powder
# Image: ILSVRC2012_val_00035194.JPEG
# Confidence before imputation: [[0.9477266]]
# Confidence after imputation: [[0.00034738]]
# The confidence increase raw: [-0.94737923]
# The drop in confidence percentage: [[99.96335]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([463])
# Target class: bucket
# Image: ILSVRC2012_val_00013968.JPEG
# Confidence before imputation: [[0.9963444]]
# Confidence after imputation: [[0.98806214]]
# The confidence increase raw: [-0.00828224]
# The drop in confidence percentage: [[0.83126324]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([251])
# Target class: dalmatian
# Image: ILSVRC2012_val_00007289.JPEG
# Confidence before imputation: [[0.55817205]]
# Confidence after imputation: [[0.01304922]]
# The confidence increase raw: [-0.5451228]
# The drop in confidence percentage: [[97.66215]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([741])
# Target class: prayer_rug
# Image: ILSVRC2012_val_00035626.JPEG
# Confidence before imputation: [[0.42136747]]
# Confidence after imputation: [[0.31901214]]
# The confidence increase raw: [-0.10235533]
# The drop in confidence percentage: [[24.291227]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([262])
# Target class: Brabancon_griffon
# Image: ILSVRC2012_val_00001925.JPEG
# Confidence before imputation: [[0.99985516]]
# Confidence after imputation: [[0.8222494]]
# The confidence increase raw: [-0.17760575]
# The drop in confidence percentage: [[17.763147]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([218])
# Target class: Welsh_springer_spaniel
# Image: ILSVRC2012_val_00018556.JPEG
# Confidence before imputation: [[0.9974482]]
# Confidence after imputation: [[0.9507959]]
# The confidence increase raw: [-0.04665232]
# The drop in confidence percentage: [[4.677167]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([966])
# Target class: red_wine
# Image: ILSVRC2012_val_00005887.JPEG
# Confidence before imputation: [[0.7028489]]
# Confidence after imputation: [[0.05695974]]
# The confidence increase raw: [-0.64588916]
# The drop in confidence percentage: [[91.89588]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([237])
# Target class: miniature_pinscher
# Image: ILSVRC2012_val_00037546.JPEG
# Confidence before imputation: [[0.46221057]]
# Confidence after imputation: [[0.40796962]]
# The confidence increase raw: [-0.05424094]
# The drop in confidence percentage: [[11.735115]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([363])
# Target class: armadillo
# Image: ILSVRC2012_val_00037983.JPEG
# Confidence before imputation: [[0.7877988]]
# Confidence after imputation: [[0.66094]]
# The confidence increase raw: [-0.12685883]
# The drop in confidence percentage: [[16.102947]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([216])
# Target class: clumber
# Image: ILSVRC2012_val_00028321.JPEG
# Confidence before imputation: [[0.99669194]]
# Confidence after imputation: [[0.9837599]]
# The confidence increase raw: [-0.01293206]
# The drop in confidence percentage: [[1.2974983]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([391])
# Target class: coho
# Image: ILSVRC2012_val_00006292.JPEG
# Confidence before imputation: [[0.9069994]]
# Confidence after imputation: [[0.62225527]]
# The confidence increase raw: [-0.28474414]
# The drop in confidence percentage: [[31.394083]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([670])
# Target class: motor_scooter
# Image: ILSVRC2012_val_00010227.JPEG
# Confidence before imputation: [[0.91163695]]
# Confidence after imputation: [[0.83378726]]
# The confidence increase raw: [-0.07784969]
# The drop in confidence percentage: [[8.539549]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([835])
# Target class: sundial
# Image: ILSVRC2012_val_00020722.JPEG
# Confidence before imputation: [[0.9939703]]
# Confidence after imputation: [[0.12325652]]
# The confidence increase raw: [-0.8707138]
# The drop in confidence percentage: [[87.59958]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([758])
# Target class: reel
# Image: ILSVRC2012_val_00010561.JPEG
# Confidence before imputation: [[0.9828911]]
# Confidence after imputation: [[0.81986964]]
# The confidence increase raw: [-0.16302145]
# The drop in confidence percentage: [[16.585913]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([841])
# Target class: sweatshirt
# Image: ILSVRC2012_val_00040482.JPEG
# Confidence before imputation: [[0.33855897]]
# Confidence after imputation: [[0.0006283]]
# The confidence increase raw: [-0.33793068]
# The drop in confidence percentage: [[99.81442]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([832])
# Target class: stupa
# Image: ILSVRC2012_val_00042051.JPEG
# Confidence before imputation: [[0.99094313]]
# Confidence after imputation: [[0.99900997]]
# The confidence increase raw: [0.00806683]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([78])
# Target class: tick
# Image: ILSVRC2012_val_00001760.JPEG
# Confidence before imputation: [[0.99909043]]
# Confidence after imputation: [[0.84288913]]
# The confidence increase raw: [-0.1562013]
# The drop in confidence percentage: [[15.634351]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([473])
# Target class: can_opener
# Image: ILSVRC2012_val_00021865.JPEG
# Confidence before imputation: [[0.25362217]]
# Confidence after imputation: [[0.00839173]]
# The confidence increase raw: [-0.24523045]
# The drop in confidence percentage: [[96.69125]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([450])
# Target class: bobsled
# Image: ILSVRC2012_val_00010828.JPEG
# Confidence before imputation: [[0.65975416]]
# Confidence after imputation: [[0.5258404]]
# The confidence increase raw: [-0.13391376]
# The drop in confidence percentage: [[20.297523]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([527])
# Target class: desktop_computer
# Image: ILSVRC2012_val_00043847.JPEG
# Confidence before imputation: [[0.50488144]]
# Confidence after imputation: [[0.04843586]]
# The confidence increase raw: [-0.45644557]
# The drop in confidence percentage: [[90.40649]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([811])
# Target class: space_heater
# Image: ILSVRC2012_val_00036917.JPEG
# Confidence before imputation: [[0.98651206]]
# Confidence after imputation: [[0.84541273]]
# The confidence increase raw: [-0.14109933]
# The drop in confidence percentage: [[14.30285]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([621])
# Target class: lawn_mower
# Image: ILSVRC2012_val_00047053.JPEG
# Confidence before imputation: [[0.9914346]]
# Confidence after imputation: [[0.9143261]]
# The confidence increase raw: [-0.0771085]
# The drop in confidence percentage: [[7.7774673]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([319])
# Target class: dragonfly
# Image: ILSVRC2012_val_00002225.JPEG
# Confidence before imputation: [[0.60956043]]
# Confidence after imputation: [[0.388715]]
# The confidence increase raw: [-0.22084543]
# The drop in confidence percentage: [[36.230278]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([361])
# Target class: skunk
# Image: ILSVRC2012_val_00014391.JPEG
# Confidence before imputation: [[0.99723524]]
# Confidence after imputation: [[0.9814719]]
# The confidence increase raw: [-0.01576334]
# The drop in confidence percentage: [[1.5807046]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([628])
# Target class: liner
# Image: ILSVRC2012_val_00023265.JPEG
# Confidence before imputation: [[0.9719863]]
# Confidence after imputation: [[0.9877787]]
# The confidence increase raw: [0.01579243]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([113])
# Target class: snail
# Image: ILSVRC2012_val_00025722.JPEG
# Confidence before imputation: [[0.797686]]
# Confidence after imputation: [[0.7745581]]
# The confidence increase raw: [-0.02312785]
# The drop in confidence percentage: [[2.8993683]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([491])
# Target class: chain_saw
# Image: ILSVRC2012_val_00035266.JPEG
# Confidence before imputation: [[0.9998068]]
# Confidence after imputation: [[0.9824426]]
# The confidence increase raw: [-0.0173642]
# The drop in confidence percentage: [[1.7367558]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([616])
# Target class: knot
# Image: ILSVRC2012_val_00000334.JPEG
# Confidence before imputation: [[0.29356125]]
# Confidence after imputation: [[0.00063323]]
# The confidence increase raw: [-0.292928]
# The drop in confidence percentage: [[99.784294]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([799])
# Target class: sliding_door
# Image: ILSVRC2012_val_00009316.JPEG
# Confidence before imputation: [[0.1365489]]
# Confidence after imputation: [[0.00349754]]
# The confidence increase raw: [-0.13305137]
# The drop in confidence percentage: [[97.438614]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([980])
# Target class: volcano
# Image: ILSVRC2012_val_00037959.JPEG
# Confidence before imputation: [[0.9998474]]
# Confidence after imputation: [[0.99453473]]
# The confidence increase raw: [-0.00531268]
# The drop in confidence percentage: [[0.5313492]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([470])
# Target class: candle
# Image: ILSVRC2012_val_00015267.JPEG
# Confidence before imputation: [[0.3927186]]
# Confidence after imputation: [[0.501308]]
# The confidence increase raw: [0.10858941]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([587])
# Target class: hammer
# Image: ILSVRC2012_val_00045274.JPEG
# Confidence before imputation: [[0.28045362]]
# Confidence after imputation: [[0.01968795]]
# The confidence increase raw: [-0.26076567]
# The drop in confidence percentage: [[92.979965]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([357])
# Target class: mink
# Image: ILSVRC2012_val_00005621.JPEG
# Confidence before imputation: [[0.9857269]]
# Confidence after imputation: [[0.49814937]]
# The confidence increase raw: [-0.48757753]
# The drop in confidence percentage: [[49.463757]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([192])
# Target class: cairn
# Image: ILSVRC2012_val_00009324.JPEG
# Confidence before imputation: [[0.84707665]]
# Confidence after imputation: [[0.9424471]]
# The confidence increase raw: [0.09537047]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([373])
# Target class: macaque
# Image: ILSVRC2012_val_00036612.JPEG
# Confidence before imputation: [[0.9876736]]
# Confidence after imputation: [[0.55781555]]
# The confidence increase raw: [-0.42985803]
# The drop in confidence percentage: [[43.522278]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([365])
# Target class: orangutan
# Image: ILSVRC2012_val_00012167.JPEG
# Confidence before imputation: [[0.99999034]]
# Confidence after imputation: [[0.9962115]]
# The confidence increase raw: [-0.00377882]
# The drop in confidence percentage: [[0.3778852]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([661])
# Target class: Model_T
# Image: ILSVRC2012_val_00013826.JPEG
# Confidence before imputation: [[0.9717172]]
# Confidence after imputation: [[0.7831999]]
# The confidence increase raw: [-0.18851727]
# The drop in confidence percentage: [[19.400427]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([882])
# Target class: vacuum
# Image: ILSVRC2012_val_00039615.JPEG
# Confidence before imputation: [[0.9996977]]
# Confidence after imputation: [[0.9996513]]
# The confidence increase raw: [-4.6372414e-05]
# The drop in confidence percentage: [[0.00463864]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([276])
# Target class: hyena
# Image: ILSVRC2012_val_00003550.JPEG
# Confidence before imputation: [[0.86445737]]
# Confidence after imputation: [[0.42987633]]
# The confidence increase raw: [-0.43458104]
# The drop in confidence percentage: [[50.272118]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([575])
# Target class: golfcart
# Image: ILSVRC2012_val_00018661.JPEG
# Confidence before imputation: [[0.72963035]]
# Confidence after imputation: [[0.03375118]]
# The confidence increase raw: [-0.69587916]
# The drop in confidence percentage: [[95.37421]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([550])
# Target class: espresso_maker
# Image: ILSVRC2012_val_00037578.JPEG
# Confidence before imputation: [[0.999302]]
# Confidence after imputation: [[0.35033977]]
# The confidence increase raw: [-0.64896226]
# The drop in confidence percentage: [[64.94156]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([829])
# Target class: streetcar
# Image: ILSVRC2012_val_00032692.JPEG
# Confidence before imputation: [[0.95930266]]
# Confidence after imputation: [[0.16327108]]
# The confidence increase raw: [-0.7960316]
# The drop in confidence percentage: [[82.98023]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([665])
# Target class: moped
# Image: ILSVRC2012_val_00022024.JPEG
# Confidence before imputation: [[0.67763793]]
# Confidence after imputation: [[0.24399373]]
# The confidence increase raw: [-0.4336442]
# The drop in confidence percentage: [[63.993496]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([611])
# Target class: jigsaw_puzzle
# Image: ILSVRC2012_val_00011285.JPEG
# Confidence before imputation: [[0.62892383]]
# Confidence after imputation: [[0.6654932]]
# The confidence increase raw: [0.03656936]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([822])
# Target class: steel_drum
# Image: ILSVRC2012_val_00017859.JPEG
# Confidence before imputation: [[0.77322924]]
# Confidence after imputation: [[0.10208079]]
# The confidence increase raw: [-0.6711484]
# The drop in confidence percentage: [[86.79812]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([971])
# Target class: bubble
# Image: ILSVRC2012_val_00025713.JPEG
# Confidence before imputation: [[0.9995573]]
# Confidence after imputation: [[0.05204168]]
# The confidence increase raw: [-0.9475156]
# The drop in confidence percentage: [[94.793526]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([635])
# Target class: magnetic_compass
# Image: ILSVRC2012_val_00027390.JPEG
# Confidence before imputation: [[0.53224224]]
# Confidence after imputation: [[0.99859804]]
# The confidence increase raw: [0.4663558]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([945])
# Target class: bell_pepper
# Image: ILSVRC2012_val_00045695.JPEG
# Confidence before imputation: [[0.9865107]]
# Confidence after imputation: [[0.8386105]]
# The confidence increase raw: [-0.14790022]
# The drop in confidence percentage: [[14.992258]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([255])
# Target class: Leonberg
# Image: ILSVRC2012_val_00038690.JPEG
# Confidence before imputation: [[0.99999917]]
# Confidence after imputation: [[0.99018455]]
# The confidence increase raw: [-0.00981462]
# The drop in confidence percentage: [[0.98146284]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([26])
# Target class: common_newt
# Image: ILSVRC2012_val_00016934.JPEG
# Confidence before imputation: [[0.94055325]]
# Confidence after imputation: [[0.01567127]]
# The confidence increase raw: [-0.924882]
# The drop in confidence percentage: [[98.333824]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([983])
# Target class: scuba_diver
# Image: ILSVRC2012_val_00027410.JPEG
# Confidence before imputation: [[0.90833265]]
# Confidence after imputation: [[0.5464789]]
# The confidence increase raw: [-0.36185372]
# The drop in confidence percentage: [[39.837135]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([355])
# Target class: llama
# Image: ILSVRC2012_val_00039936.JPEG
# Confidence before imputation: [[0.99714404]]
# Confidence after imputation: [[0.09883205]]
# The confidence increase raw: [-0.898312]
# The drop in confidence percentage: [[90.088486]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([100])
# Target class: black_swan
# Image: ILSVRC2012_val_00025764.JPEG
# Confidence before imputation: [[0.97658575]]
# Confidence after imputation: [[0.01021914]]
# The confidence increase raw: [-0.9663666]
# The drop in confidence percentage: [[98.95358]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([443])
# Target class: bib
# Image: ILSVRC2012_val_00024909.JPEG
# Confidence before imputation: [[0.9738321]]
# Confidence after imputation: [[0.24891415]]
# The confidence increase raw: [-0.7249179]
# The drop in confidence percentage: [[74.43972]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([863])
# Target class: totem_pole
# Image: ILSVRC2012_val_00003979.JPEG
# Confidence before imputation: [[0.969088]]
# Confidence after imputation: [[0.89697915]]
# The confidence increase raw: [-0.07210886]
# The drop in confidence percentage: [[7.4408994]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([902])
# Target class: whistle
# Image: ILSVRC2012_val_00035948.JPEG
# Confidence before imputation: [[0.81057715]]
# Confidence after imputation: [[0.00572751]]
# The confidence increase raw: [-0.8048496]
# The drop in confidence percentage: [[99.293396]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([219])
# Target class: cocker_spaniel
# Image: ILSVRC2012_val_00044730.JPEG
# Confidence before imputation: [[0.99981445]]
# Confidence after imputation: [[0.99706954]]
# The confidence increase raw: [-0.00274491]
# The drop in confidence percentage: [[0.27454224]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([839])
# Target class: suspension_bridge
# Image: ILSVRC2012_val_00041283.JPEG
# Confidence before imputation: [[0.956251]]
# Confidence after imputation: [[0.24510583]]
# The confidence increase raw: [-0.71114516]
# The drop in confidence percentage: [[74.36804]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
#
# Number of images processed: 100
# Average Drop in Confidence: [[45.65416]]%
# Average Increase in Confidence: [[10.]]%

# %%
cam_type = CAMType.GRAD_CAM_PLUS_PLUS

# Initialize metrics
total_drop_in_conf = 0
total_increase_in_conf = 0
num_images = 0  # Track number of processed images

# Process the randomly selected images
for filename in random_image_names:
    img_path = os.path.join(input_folder, filename)

    if os.path.exists(img_path):  # Ensure the file exists
        # Execute CAM for the current image
        gray_scale, input_tensor = execute_cam(img_path=img_path, model=model, target_layers=target_layers, cam_type=cam_type)
        
        # Add threshold
        threshold = np.percentile(gray_scale, 50)
        
        gray_scale[gray_scale < threshold] = 0
        # gray_scale = gray_scale < threshold

        # Calculate predicted class and confidence score change
        predicted_class = model(input_tensor).max(1)[-1]
        targets = [ClassifierOutputSoftmaxTarget(predicted_class)]

        scores, scores_before, scores_after, visualizations = cam_metric(
            input_tensor, gray_scale, targets, model, return_visualization=True
        )

        # Calculate Drop in Confidence and Increase in Confidence
        drop_in_conf = drop_in_conf_metric(input_tensor, gray_scale, targets, model)
        increase_in_conf = increase_in_conf_metric(input_tensor, gray_scale, targets, model)

        # Accumulate the scores for averaging
        total_drop_in_conf += drop_in_conf
        total_increase_in_conf += increase_in_conf
        num_images += 1  # Increment image count

        # Process the visualization for display and scoring
        score = scores[0]

        # Save images to imputated folder
        visualization = visualizations[0].cpu().numpy().transpose((1, 2, 0))
        visualization = deprocess_image(visualization)
        Image.fromarray(visualization).save(os.path.join(imputated_folder, filename))

        # Print individual results
        print(f"Image: {filename}")
        print(f"Confidence before imputation: {scores_before}")
        print(f"Confidence after imputation: {scores_after}")
        print(f"The confidence increase raw: {score}")
        print(f"The drop in confidence percentage: {drop_in_conf}%")
        print(f"The increase in confidence: {increase_in_conf}")
        print("----------------------------------------")

# Calculate and print averages after processing all images
if num_images > 0:
    avg_drop_in_conf = total_drop_in_conf / num_images
    avg_increase_in_conf = total_increase_in_conf / num_images * 100
    print(f"\nNumber of images processed: {num_images}")
    print(f"Average Drop in Confidence: {avg_drop_in_conf}%")
    print(f"Average Increase in Confidence: {avg_increase_in_conf}%")
else:
    print("No valid images found in the specified folder.")
# Out:
# Executing CAM on VGG with target layer Conv2d:
# tensor([605])
# Target class: iPod
# Image: ILSVRC2012_val_00048014.JPEG
# Confidence before imputation: [[0.9759646]]
# Confidence after imputation: [[0.8933943]]
# The confidence increase raw: [-0.08257031]
# The drop in confidence percentage: [[8.460381]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([748])
# Target class: purse
# Image: ILSVRC2012_val_00040662.JPEG
# Confidence before imputation: [[0.42008683]]
# Confidence after imputation: [[0.01470881]]
# The confidence increase raw: [-0.405378]
# The drop in confidence percentage: [[96.49863]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([898])
# Target class: water_bottle
# Image: ILSVRC2012_val_00021194.JPEG
# Confidence before imputation: [[0.24797332]]
# Confidence after imputation: [[0.00360898]]
# The confidence increase raw: [-0.24436434]
# The drop in confidence percentage: [[98.54461]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([760])
# Target class: refrigerator
# Image: ILSVRC2012_val_00038840.JPEG
# Confidence before imputation: [[0.9940416]]
# Confidence after imputation: [[0.16833514]]
# The confidence increase raw: [-0.8257065]
# The drop in confidence percentage: [[83.06559]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([980])
# Target class: volcano
# Image: ILSVRC2012_val_00026519.JPEG
# Confidence before imputation: [[0.8553798]]
# Confidence after imputation: [[0.14350034]]
# The confidence increase raw: [-0.7118795]
# The drop in confidence percentage: [[83.22379]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([126])
# Target class: isopod
# Image: ILSVRC2012_val_00026939.JPEG
# Confidence before imputation: [[0.99842215]]
# Confidence after imputation: [[0.9547033]]
# The confidence increase raw: [-0.04371887]
# The drop in confidence percentage: [[4.3787966]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([209])
# Target class: Chesapeake_Bay_retriever
# Image: ILSVRC2012_val_00000022.JPEG
# Confidence before imputation: [[0.06324018]]
# Confidence after imputation: [[0.00744805]]
# The confidence increase raw: [-0.05579212]
# The drop in confidence percentage: [[88.222595]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([937])
# Target class: broccoli
# Image: ILSVRC2012_val_00000165.JPEG
# Confidence before imputation: [[0.9990583]]
# Confidence after imputation: [[0.9991504]]
# The confidence increase raw: [9.2089176e-05]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([203])
# Target class: West_Highland_white_terrier
# Image: ILSVRC2012_val_00028945.JPEG
# Confidence before imputation: [[0.904776]]
# Confidence after imputation: [[0.83298784]]
# The confidence increase raw: [-0.07178813]
# The drop in confidence percentage: [[7.9343543]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([954])
# Target class: banana
# Image: ILSVRC2012_val_00032674.JPEG
# Confidence before imputation: [[0.64645135]]
# Confidence after imputation: [[0.0960395]]
# The confidence increase raw: [-0.5504119]
# The drop in confidence percentage: [[85.14359]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([561])
# Target class: forklift
# Image: ILSVRC2012_val_00026695.JPEG
# Confidence before imputation: [[0.9999956]]
# Confidence after imputation: [[0.8122417]]
# The confidence increase raw: [-0.18775392]
# The drop in confidence percentage: [[18.775475]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([850])
# Target class: teddy
# Image: ILSVRC2012_val_00043106.JPEG
# Confidence before imputation: [[0.9326974]]
# Confidence after imputation: [[0.34984812]]
# The confidence increase raw: [-0.58284926]
# The drop in confidence percentage: [[62.490715]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([495])
# Target class: china_cabinet
# Image: ILSVRC2012_val_00038333.JPEG
# Confidence before imputation: [[0.99724907]]
# Confidence after imputation: [[0.9858436]]
# The confidence increase raw: [-0.01140547]
# The drop in confidence percentage: [[1.143693]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([12])
# Target class: house_finch
# Image: ILSVRC2012_val_00018162.JPEG
# Confidence before imputation: [[0.852396]]
# Confidence after imputation: [[0.13685033]]
# The confidence increase raw: [-0.71554565]
# The drop in confidence percentage: [[83.94521]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([694])
# Target class: paddlewheel
# Image: ILSVRC2012_val_00004863.JPEG
# Confidence before imputation: [[0.9999994]]
# Confidence after imputation: [[0.99939644]]
# The confidence increase raw: [-0.00060296]
# The drop in confidence percentage: [[0.06029609]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([248])
# Target class: Eskimo_dog
# Image: ILSVRC2012_val_00034851.JPEG
# Confidence before imputation: [[0.4604159]]
# Confidence after imputation: [[0.2563837]]
# The confidence increase raw: [-0.20403221]
# The drop in confidence percentage: [[44.314762]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([305])
# Target class: dung_beetle
# Image: ILSVRC2012_val_00004517.JPEG
# Confidence before imputation: [[0.92013]]
# Confidence after imputation: [[0.75630784]]
# The confidence increase raw: [-0.16382217]
# The drop in confidence percentage: [[17.804243]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([98])
# Target class: red-breasted_merganser
# Image: ILSVRC2012_val_00010810.JPEG
# Confidence before imputation: [[0.68175596]]
# Confidence after imputation: [[0.3876188]]
# The confidence increase raw: [-0.29413715]
# The drop in confidence percentage: [[43.144054]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([763])
# Target class: revolver
# Image: ILSVRC2012_val_00011824.JPEG
# Confidence before imputation: [[0.9994036]]
# Confidence after imputation: [[0.96143556]]
# The confidence increase raw: [-0.03796804]
# The drop in confidence percentage: [[3.7990696]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([746])
# Target class: puck
# Image: ILSVRC2012_val_00020485.JPEG
# Confidence before imputation: [[0.7053595]]
# Confidence after imputation: [[0.01008496]]
# The confidence increase raw: [-0.69527453]
# The drop in confidence percentage: [[98.57024]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([735])
# Target class: poncho
# Image: ILSVRC2012_val_00048173.JPEG
# Confidence before imputation: [[0.9730132]]
# Confidence after imputation: [[0.00491724]]
# The confidence increase raw: [-0.96809596]
# The drop in confidence percentage: [[99.49464]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([211])
# Target class: vizsla
# Image: ILSVRC2012_val_00041393.JPEG
# Confidence before imputation: [[0.9897141]]
# Confidence after imputation: [[0.97626776]]
# The confidence increase raw: [-0.01344633]
# The drop in confidence percentage: [[1.3586076]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([807])
# Target class: solar_dish
# Image: ILSVRC2012_val_00033662.JPEG
# Confidence before imputation: [[0.5625051]]
# Confidence after imputation: [[0.00375367]]
# The confidence increase raw: [-0.55875146]
# The drop in confidence percentage: [[99.33269]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([653])
# Target class: milk_can
# Image: ILSVRC2012_val_00045303.JPEG
# Confidence before imputation: [[0.45696172]]
# Confidence after imputation: [[0.140118]]
# The confidence increase raw: [-0.31684372]
# The drop in confidence percentage: [[69.337036]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([586])
# Target class: half_track
# Image: ILSVRC2012_val_00004455.JPEG
# Confidence before imputation: [[0.9999417]]
# Confidence after imputation: [[0.9976434]]
# The confidence increase raw: [-0.0022983]
# The drop in confidence percentage: [[0.22984293]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([962])
# Target class: meat_loaf
# Image: ILSVRC2012_val_00011500.JPEG
# Confidence before imputation: [[0.82238984]]
# Confidence after imputation: [[0.5132882]]
# The confidence increase raw: [-0.30910164]
# The drop in confidence percentage: [[37.58578]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([641])
# Target class: maraca
# Image: ILSVRC2012_val_00025962.JPEG
# Confidence before imputation: [[0.7052517]]
# Confidence after imputation: [[0.00175814]]
# The confidence increase raw: [-0.70349354]
# The drop in confidence percentage: [[99.7507]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([536])
# Target class: dock
# Image: ILSVRC2012_val_00043584.JPEG
# Confidence before imputation: [[0.49611756]]
# Confidence after imputation: [[0.00981852]]
# The confidence increase raw: [-0.48629904]
# The drop in confidence percentage: [[98.02093]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([695])
# Target class: padlock
# Image: ILSVRC2012_val_00036038.JPEG
# Confidence before imputation: [[0.9970312]]
# Confidence after imputation: [[0.9952165]]
# The confidence increase raw: [-0.00181472]
# The drop in confidence percentage: [[0.18201265]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([958])
# Target class: hay
# Image: ILSVRC2012_val_00001159.JPEG
# Confidence before imputation: [[0.9706044]]
# Confidence after imputation: [[0.20520659]]
# The confidence increase raw: [-0.76539785]
# The drop in confidence percentage: [[78.85786]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([6])
# Target class: stingray
# Image: ILSVRC2012_val_00036157.JPEG
# Confidence before imputation: [[0.9078361]]
# Confidence after imputation: [[0.07767619]]
# The confidence increase raw: [-0.8301599]
# The drop in confidence percentage: [[91.44381]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([267])
# Target class: standard_poodle
# Image: ILSVRC2012_val_00047597.JPEG
# Confidence before imputation: [[0.800983]]
# Confidence after imputation: [[0.7818295]]
# The confidence increase raw: [-0.01915354]
# The drop in confidence percentage: [[2.3912537]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([597])
# Target class: holster
# Image: ILSVRC2012_val_00044337.JPEG
# Confidence before imputation: [[0.95589864]]
# Confidence after imputation: [[0.00549234]]
# The confidence increase raw: [-0.9504063]
# The drop in confidence percentage: [[99.42543]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([458])
# Target class: brass
# Image: ILSVRC2012_val_00003755.JPEG
# Confidence before imputation: [[0.7906359]]
# Confidence after imputation: [[0.85829526]]
# The confidence increase raw: [0.06765938]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([388])
# Target class: giant_panda
# Image: ILSVRC2012_val_00043447.JPEG
# Confidence before imputation: [[1.]]
# Confidence after imputation: [[0.99999964]]
# The confidence increase raw: [-3.5762787e-07]
# The drop in confidence percentage: [[3.5762787e-05]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([721])
# Target class: pillow
# Image: ILSVRC2012_val_00031518.JPEG
# Confidence before imputation: [[0.26630247]]
# Confidence after imputation: [[0.02807026]]
# The confidence increase raw: [-0.23823221]
# The drop in confidence percentage: [[89.45926]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([232])
# Target class: Border_collie
# Image: ILSVRC2012_val_00041929.JPEG
# Confidence before imputation: [[0.763132]]
# Confidence after imputation: [[0.7601672]]
# The confidence increase raw: [-0.00296479]
# The drop in confidence percentage: [[0.38850352]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([792])
# Target class: shovel
# Image: ILSVRC2012_val_00010950.JPEG
# Confidence before imputation: [[0.6403869]]
# Confidence after imputation: [[0.00623952]]
# The confidence increase raw: [-0.63414735]
# The drop in confidence percentage: [[99.02566]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([313])
# Target class: walking_stick
# Image: ILSVRC2012_val_00023940.JPEG
# Confidence before imputation: [[0.18065749]]
# Confidence after imputation: [[0.0066804]]
# The confidence increase raw: [-0.17397709]
# The drop in confidence percentage: [[96.30218]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([703])
# Target class: park_bench
# Image: ILSVRC2012_val_00034458.JPEG
# Confidence before imputation: [[0.96288735]]
# Confidence after imputation: [[0.0699343]]
# The confidence increase raw: [-0.89295304]
# The drop in confidence percentage: [[92.73702]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([752])
# Target class: racket
# Image: ILSVRC2012_val_00003772.JPEG
# Confidence before imputation: [[0.5566144]]
# Confidence after imputation: [[0.0315061]]
# The confidence increase raw: [-0.5251083]
# The drop in confidence percentage: [[94.33968]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([658])
# Target class: mitten
# Image: ILSVRC2012_val_00017173.JPEG
# Confidence before imputation: [[0.44766384]]
# Confidence after imputation: [[0.42024764]]
# The confidence increase raw: [-0.0274162]
# The drop in confidence percentage: [[6.124283]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([551])
# Target class: face_powder
# Image: ILSVRC2012_val_00035194.JPEG
# Confidence before imputation: [[0.9477266]]
# Confidence after imputation: [[0.00452676]]
# The confidence increase raw: [-0.9431999]
# The drop in confidence percentage: [[99.52236]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([463])
# Target class: bucket
# Image: ILSVRC2012_val_00013968.JPEG
# Confidence before imputation: [[0.9963444]]
# Confidence after imputation: [[0.9705958]]
# The confidence increase raw: [-0.02574861]
# The drop in confidence percentage: [[2.5843081]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([251])
# Target class: dalmatian
# Image: ILSVRC2012_val_00007289.JPEG
# Confidence before imputation: [[0.55817205]]
# Confidence after imputation: [[0.01161881]]
# The confidence increase raw: [-0.54655325]
# The drop in confidence percentage: [[97.91842]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([741])
# Target class: prayer_rug
# Image: ILSVRC2012_val_00035626.JPEG
# Confidence before imputation: [[0.42136747]]
# Confidence after imputation: [[0.01083635]]
# The confidence increase raw: [-0.41053113]
# The drop in confidence percentage: [[97.42829]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([262])
# Target class: Brabancon_griffon
# Image: ILSVRC2012_val_00001925.JPEG
# Confidence before imputation: [[0.99985516]]
# Confidence after imputation: [[0.8854245]]
# The confidence increase raw: [-0.11443067]
# The drop in confidence percentage: [[11.444724]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([218])
# Target class: Welsh_springer_spaniel
# Image: ILSVRC2012_val_00018556.JPEG
# Confidence before imputation: [[0.9974482]]
# Confidence after imputation: [[0.9752661]]
# The confidence increase raw: [-0.02218211]
# The drop in confidence percentage: [[2.2238855]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([966])
# Target class: red_wine
# Image: ILSVRC2012_val_00005887.JPEG
# Confidence before imputation: [[0.7028489]]
# Confidence after imputation: [[0.27396902]]
# The confidence increase raw: [-0.4288799]
# The drop in confidence percentage: [[61.020214]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([237])
# Target class: miniature_pinscher
# Image: ILSVRC2012_val_00037546.JPEG
# Confidence before imputation: [[0.46221057]]
# Confidence after imputation: [[0.1888369]]
# The confidence increase raw: [-0.27337366]
# The drop in confidence percentage: [[59.14483]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([363])
# Target class: armadillo
# Image: ILSVRC2012_val_00037983.JPEG
# Confidence before imputation: [[0.7877988]]
# Confidence after imputation: [[0.8820132]]
# The confidence increase raw: [0.09421438]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([216])
# Target class: clumber
# Image: ILSVRC2012_val_00028321.JPEG
# Confidence before imputation: [[0.99669194]]
# Confidence after imputation: [[0.9881989]]
# The confidence increase raw: [-0.00849307]
# The drop in confidence percentage: [[0.8521254]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([391])
# Target class: coho
# Image: ILSVRC2012_val_00006292.JPEG
# Confidence before imputation: [[0.9069994]]
# Confidence after imputation: [[0.6677946]]
# The confidence increase raw: [-0.23920482]
# The drop in confidence percentage: [[26.373207]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([670])
# Target class: motor_scooter
# Image: ILSVRC2012_val_00010227.JPEG
# Confidence before imputation: [[0.91163695]]
# Confidence after imputation: [[0.9001713]]
# The confidence increase raw: [-0.01146567]
# The drop in confidence percentage: [[1.2577012]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([835])
# Target class: sundial
# Image: ILSVRC2012_val_00020722.JPEG
# Confidence before imputation: [[0.9939703]]
# Confidence after imputation: [[0.17899561]]
# The confidence increase raw: [-0.81497467]
# The drop in confidence percentage: [[81.99186]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([758])
# Target class: reel
# Image: ILSVRC2012_val_00010561.JPEG
# Confidence before imputation: [[0.9828911]]
# Confidence after imputation: [[0.13535398]]
# The confidence increase raw: [-0.8475371]
# The drop in confidence percentage: [[86.229]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([841])
# Target class: sweatshirt
# Image: ILSVRC2012_val_00040482.JPEG
# Confidence before imputation: [[0.33855897]]
# Confidence after imputation: [[0.00361305]]
# The confidence increase raw: [-0.33494592]
# The drop in confidence percentage: [[98.932816]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([832])
# Target class: stupa
# Image: ILSVRC2012_val_00042051.JPEG
# Confidence before imputation: [[0.99094313]]
# Confidence after imputation: [[0.9984061]]
# The confidence increase raw: [0.00746298]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([78])
# Target class: tick
# Image: ILSVRC2012_val_00001760.JPEG
# Confidence before imputation: [[0.99909043]]
# Confidence after imputation: [[0.9718242]]
# The confidence increase raw: [-0.0272662]
# The drop in confidence percentage: [[2.7291028]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([473])
# Target class: can_opener
# Image: ILSVRC2012_val_00021865.JPEG
# Confidence before imputation: [[0.25362217]]
# Confidence after imputation: [[0.00623615]]
# The confidence increase raw: [-0.24738602]
# The drop in confidence percentage: [[97.54117]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([450])
# Target class: bobsled
# Image: ILSVRC2012_val_00010828.JPEG
# Confidence before imputation: [[0.65975416]]
# Confidence after imputation: [[0.13671286]]
# The confidence increase raw: [-0.5230413]
# The drop in confidence percentage: [[79.27821]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([527])
# Target class: desktop_computer
# Image: ILSVRC2012_val_00043847.JPEG
# Confidence before imputation: [[0.50488144]]
# Confidence after imputation: [[0.13238442]]
# The confidence increase raw: [-0.37249702]
# The drop in confidence percentage: [[73.779106]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([811])
# Target class: space_heater
# Image: ILSVRC2012_val_00036917.JPEG
# Confidence before imputation: [[0.98651206]]
# Confidence after imputation: [[0.7805133]]
# The confidence increase raw: [-0.20599878]
# The drop in confidence percentage: [[20.881527]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([621])
# Target class: lawn_mower
# Image: ILSVRC2012_val_00047053.JPEG
# Confidence before imputation: [[0.9914346]]
# Confidence after imputation: [[0.928406]]
# The confidence increase raw: [-0.06302857]
# The drop in confidence percentage: [[6.357311]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([319])
# Target class: dragonfly
# Image: ILSVRC2012_val_00002225.JPEG
# Confidence before imputation: [[0.60956043]]
# Confidence after imputation: [[0.70964646]]
# The confidence increase raw: [0.10008603]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([361])
# Target class: skunk
# Image: ILSVRC2012_val_00014391.JPEG
# Confidence before imputation: [[0.99723524]]
# Confidence after imputation: [[0.97297645]]
# The confidence increase raw: [-0.02425879]
# The drop in confidence percentage: [[2.4326048]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([628])
# Target class: liner
# Image: ILSVRC2012_val_00023265.JPEG
# Confidence before imputation: [[0.9719863]]
# Confidence after imputation: [[0.98060715]]
# The confidence increase raw: [0.00862086]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([113])
# Target class: snail
# Image: ILSVRC2012_val_00025722.JPEG
# Confidence before imputation: [[0.797686]]
# Confidence after imputation: [[0.9297382]]
# The confidence increase raw: [0.13205224]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([491])
# Target class: chain_saw
# Image: ILSVRC2012_val_00035266.JPEG
# Confidence before imputation: [[0.9998068]]
# Confidence after imputation: [[0.99744034]]
# The confidence increase raw: [-0.00236648]
# The drop in confidence percentage: [[0.23669405]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([616])
# Target class: knot
# Image: ILSVRC2012_val_00000334.JPEG
# Confidence before imputation: [[0.29356125]]
# Confidence after imputation: [[0.01858246]]
# The confidence increase raw: [-0.2749788]
# The drop in confidence percentage: [[93.66998]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([799])
# Target class: sliding_door
# Image: ILSVRC2012_val_00009316.JPEG
# Confidence before imputation: [[0.1365489]]
# Confidence after imputation: [[0.00466096]]
# The confidence increase raw: [-0.13188794]
# The drop in confidence percentage: [[96.58659]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([980])
# Target class: volcano
# Image: ILSVRC2012_val_00037959.JPEG
# Confidence before imputation: [[0.9998474]]
# Confidence after imputation: [[0.9928213]]
# The confidence increase raw: [-0.00702614]
# The drop in confidence percentage: [[0.7027208]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([470])
# Target class: candle
# Image: ILSVRC2012_val_00015267.JPEG
# Confidence before imputation: [[0.3927186]]
# Confidence after imputation: [[0.52008975]]
# The confidence increase raw: [0.12737113]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([587])
# Target class: hammer
# Image: ILSVRC2012_val_00045274.JPEG
# Confidence before imputation: [[0.28045362]]
# Confidence after imputation: [[0.3093043]]
# The confidence increase raw: [0.02885067]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([357])
# Target class: mink
# Image: ILSVRC2012_val_00005621.JPEG
# Confidence before imputation: [[0.9857269]]
# Confidence after imputation: [[0.50033724]]
# The confidence increase raw: [-0.48538965]
# The drop in confidence percentage: [[49.2418]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([192])
# Target class: cairn
# Image: ILSVRC2012_val_00009324.JPEG
# Confidence before imputation: [[0.84707665]]
# Confidence after imputation: [[0.7907823]]
# The confidence increase raw: [-0.05629438]
# The drop in confidence percentage: [[6.645725]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([373])
# Target class: macaque
# Image: ILSVRC2012_val_00036612.JPEG
# Confidence before imputation: [[0.9876736]]
# Confidence after imputation: [[0.80741596]]
# The confidence increase raw: [-0.18025762]
# The drop in confidence percentage: [[18.250729]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([365])
# Target class: orangutan
# Image: ILSVRC2012_val_00012167.JPEG
# Confidence before imputation: [[0.99999034]]
# Confidence after imputation: [[0.9883398]]
# The confidence increase raw: [-0.01165056]
# The drop in confidence percentage: [[1.1650676]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([661])
# Target class: Model_T
# Image: ILSVRC2012_val_00013826.JPEG
# Confidence before imputation: [[0.9717172]]
# Confidence after imputation: [[0.5069435]]
# The confidence increase raw: [-0.46477365]
# The drop in confidence percentage: [[47.83014]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([882])
# Target class: vacuum
# Image: ILSVRC2012_val_00039615.JPEG
# Confidence before imputation: [[0.9996977]]
# Confidence after imputation: [[0.9988985]]
# The confidence increase raw: [-0.00079918]
# The drop in confidence percentage: [[0.07994208]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([276])
# Target class: hyena
# Image: ILSVRC2012_val_00003550.JPEG
# Confidence before imputation: [[0.86445737]]
# Confidence after imputation: [[0.64131]]
# The confidence increase raw: [-0.22314739]
# The drop in confidence percentage: [[25.81358]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([575])
# Target class: golfcart
# Image: ILSVRC2012_val_00018661.JPEG
# Confidence before imputation: [[0.72963035]]
# Confidence after imputation: [[0.19834743]]
# The confidence increase raw: [-0.5312829]
# The drop in confidence percentage: [[72.81535]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([550])
# Target class: espresso_maker
# Image: ILSVRC2012_val_00037578.JPEG
# Confidence before imputation: [[0.999302]]
# Confidence after imputation: [[0.689456]]
# The confidence increase raw: [-0.30984604]
# The drop in confidence percentage: [[31.006247]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([829])
# Target class: streetcar
# Image: ILSVRC2012_val_00032692.JPEG
# Confidence before imputation: [[0.95930266]]
# Confidence after imputation: [[0.00963169]]
# The confidence increase raw: [-0.949671]
# The drop in confidence percentage: [[98.99597]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([665])
# Target class: moped
# Image: ILSVRC2012_val_00022024.JPEG
# Confidence before imputation: [[0.67763793]]
# Confidence after imputation: [[0.33706626]]
# The confidence increase raw: [-0.34057167]
# The drop in confidence percentage: [[50.258648]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([611])
# Target class: jigsaw_puzzle
# Image: ILSVRC2012_val_00011285.JPEG
# Confidence before imputation: [[0.62892383]]
# Confidence after imputation: [[0.18531689]]
# The confidence increase raw: [-0.44360694]
# The drop in confidence percentage: [[70.53429]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([822])
# Target class: steel_drum
# Image: ILSVRC2012_val_00017859.JPEG
# Confidence before imputation: [[0.77322924]]
# Confidence after imputation: [[0.04451647]]
# The confidence increase raw: [-0.7287128]
# The drop in confidence percentage: [[94.24279]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([971])
# Target class: bubble
# Image: ILSVRC2012_val_00025713.JPEG
# Confidence before imputation: [[0.9995573]]
# Confidence after imputation: [[0.1789299]]
# The confidence increase raw: [-0.82062745]
# The drop in confidence percentage: [[82.09908]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([635])
# Target class: magnetic_compass
# Image: ILSVRC2012_val_00027390.JPEG
# Confidence before imputation: [[0.53224224]]
# Confidence after imputation: [[0.99232095]]
# The confidence increase raw: [0.46007872]
# The drop in confidence percentage: [[0.]]%
# The increase in confidence: [[1.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([945])
# Target class: bell_pepper
# Image: ILSVRC2012_val_00045695.JPEG
# Confidence before imputation: [[0.9865107]]
# Confidence after imputation: [[0.98318624]]
# The confidence increase raw: [-0.00332445]
# The drop in confidence percentage: [[0.33699065]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([255])
# Target class: Leonberg
# Image: ILSVRC2012_val_00038690.JPEG
# Confidence before imputation: [[0.99999917]]
# Confidence after imputation: [[0.9953896]]
# The confidence increase raw: [-0.00460958]
# The drop in confidence percentage: [[0.46095884]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([26])
# Target class: common_newt
# Image: ILSVRC2012_val_00016934.JPEG
# Confidence before imputation: [[0.94055325]]
# Confidence after imputation: [[0.23256584]]
# The confidence increase raw: [-0.7079874]
# The drop in confidence percentage: [[75.273506]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([983])
# Target class: scuba_diver
# Image: ILSVRC2012_val_00027410.JPEG
# Confidence before imputation: [[0.90833265]]
# Confidence after imputation: [[0.18513083]]
# The confidence increase raw: [-0.7232018]
# The drop in confidence percentage: [[79.61861]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([355])
# Target class: llama
# Image: ILSVRC2012_val_00039936.JPEG
# Confidence before imputation: [[0.99714404]]
# Confidence after imputation: [[0.12522061]]
# The confidence increase raw: [-0.87192345]
# The drop in confidence percentage: [[87.44208]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([100])
# Target class: black_swan
# Image: ILSVRC2012_val_00025764.JPEG
# Confidence before imputation: [[0.97658575]]
# Confidence after imputation: [[0.7462061]]
# The confidence increase raw: [-0.23037964]
# The drop in confidence percentage: [[23.590315]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([443])
# Target class: bib
# Image: ILSVRC2012_val_00024909.JPEG
# Confidence before imputation: [[0.9738321]]
# Confidence after imputation: [[0.07098524]]
# The confidence increase raw: [-0.9028468]
# The drop in confidence percentage: [[92.710724]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([863])
# Target class: totem_pole
# Image: ILSVRC2012_val_00003979.JPEG
# Confidence before imputation: [[0.969088]]
# Confidence after imputation: [[0.9670913]]
# The confidence increase raw: [-0.0019967]
# The drop in confidence percentage: [[0.20603865]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([902])
# Target class: whistle
# Image: ILSVRC2012_val_00035948.JPEG
# Confidence before imputation: [[0.81057715]]
# Confidence after imputation: [[0.11411305]]
# The confidence increase raw: [-0.6964641]
# The drop in confidence percentage: [[85.922005]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([219])
# Target class: cocker_spaniel
# Image: ILSVRC2012_val_00044730.JPEG
# Confidence before imputation: [[0.99981445]]
# Confidence after imputation: [[0.9982735]]
# The confidence increase raw: [-0.00154096]
# The drop in confidence percentage: [[0.1541245]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
# Executing CAM on VGG with target layer Conv2d:
# tensor([839])
# Target class: suspension_bridge
# Image: ILSVRC2012_val_00041283.JPEG
# Confidence before imputation: [[0.956251]]
# Confidence after imputation: [[0.26730597]]
# The confidence increase raw: [-0.68894506]
# The drop in confidence percentage: [[72.04646]]%
# The increase in confidence: [[0.]]
# ----------------------------------------
#
# Number of images processed: 100
# Average Drop in Confidence: [[45.53167]]%
# Average Increase in Confidence: [[10.]]%

# %%
# cam_type = CAMType.SCORE_CAM

# # Initialize metrics
# total_drop_in_conf = 0
# total_increase_in_conf = 0
# num_images = 0  # Track number of processed images

# # Process the randomly selected images
# for filename in random_image_names:
#     img_path = os.path.join(input_folder, filename)

#     if os.path.exists(img_path):  # Ensure the file exists
#         # Execute CAM for the current image
#         gray_scale, input_tensor = execute_cam(img_path=img_path, model=model, target_layers=target_layers, cam_type=cam_type)
        
#         # Add threshold
#         threshold = np.percentile(gray_scale, 50)
        
#         gray_scale[gray_scale < threshold] = 0
#         # gray_scale = gray_scale < threshold

#         # Calculate predicted class and confidence score change
#         predicted_class = model(input_tensor).max(1)[-1]
#         targets = [ClassifierOutputSoftmaxTarget(predicted_class)]

#         scores, scores_before, scores_after, visualizations = cam_metric(
#             input_tensor, gray_scale, targets, model, return_visualization=True
#         )

#         # Calculate Drop in Confidence and Increase in Confidence
#         drop_in_conf = drop_in_conf_metric(input_tensor, gray_scale, targets, model)
#         increase_in_conf = increase_in_conf_metric(input_tensor, gray_scale, targets, model)

#         # Accumulate the scores for averaging
#         total_drop_in_conf += drop_in_conf
#         total_increase_in_conf += increase_in_conf
#         num_images += 1  # Increment image count

#         # Process the visualization for display and scoring
#         score = scores[0]

#         # Save images to imputated folder
#         visualization = visualizations[0].cpu().numpy().transpose((1, 2, 0))
#         visualization = deprocess_image(visualization)
#         Image.fromarray(visualization).save(os.path.join(imputated_folder, filename))

#         # Print individual results
#         print(f"Image: {filename}")
#         print(f"Confidence before imputation: {scores_before}")
#         print(f"Confidence after imputation: {scores_after}")
#         print(f"The confidence increase raw: {score}")
#         print(f"The drop in confidence percentage: {drop_in_conf}%")
#         print(f"The increase in confidence: {increase_in_conf}")
#         print("----------------------------------------")

# # Calculate and print averages after processing all images
# if num_images > 0:
#     avg_drop_in_conf = total_drop_in_conf / num_images
#     avg_increase_in_conf = total_increase_in_conf / num_images * 100
#     print(f"\nNumber of images processed: {num_images}")
#     print(f"Average Drop in Confidence: {avg_drop_in_conf}%")
#     print(f"Average Increase in Confidence: {avg_increase_in_conf}%")
# else:
#     print("No valid images found in the specified folder.")
